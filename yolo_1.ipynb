# %%
import torch

# %%
torch.cuda.is_available()

# %%
# !pip install opencv-python
# !pip install ultralytics
# !pip install numpy

# %%
import cv2
import numpy as np
from ultralytics import YOLO
print("OpenCV version:", cv2.__version__)
print("All good!")

# %%
import cv2

# Read image from file
img = cv2.imread('wife_son.jpeg')

# %%
print(img)

# %%
print("Shape:", img.shape)    # (height, width, channels)
print("Type:", img.dtype)     # uint8
print("Size:", img.size)      # total number of values

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

img = cv2.imread('wife_son.jpeg')

# Show in a window
cv2_imshow(img)

# %%
img = cv2.imread('wife_son.jpeg')

# %% [markdown]
# Reading pixel values, specific pixels

# %%
pixel = img[100,300]

# %%
print("Pixel at (100,300):", pixel)

# %%
# Read individual channels
blue  = img[100, 200, 0]
green = img[100, 200, 1]
red   = img[100, 200, 2]
print(f"B:{blue} G:{green} R:{red}")

# %%
# save a copy of the image.
cv2.imwrite('copy.png', img)
